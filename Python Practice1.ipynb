# %%
#to print a string
print("I love python")
# Out:
# I love python

# %%
#arthimetic operations and all types
a = int(input())
b = int(input())
print(a + b)
print(a - b)
print(a * b)
print(a % b)
print(a//b)
print(a**b)
print(a**0.5) #to find the square root
print(a/b)
# Out:
#  64
#  25
# 89
# 39
# 1600
# 14
# 2
# 1427247692705959881058285969449495136382746624
# 8.0
# 2.56

# %%
#to find the area of a triangle
base = int(input())
height = int(input())
area = 0.5 * base * height 
print(area)

# %%
for i in range(1,10,4):
    print(i)
# Out:
# 1
# 5
# 9

# %%
string1 = "codegnan" 
for i in string1:
    print(i)
# Out:
# c
# o
# d
# e
# g
# n
# a
# n
