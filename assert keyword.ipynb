# %%
#whether person is eligible for voting or not
n = int(input())
if (n>=18):
    print("Eligible for vote")
else:
    print("Not Eligible")
# Out:
#  17
# Not Eligible

# %% [markdown]
# #assert keyword : is used for testing

# %%
#assert

age = int(input())
assert age>=18, "age must be above 17"
print("eligible")
# Out:
#  12
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 #assert
#       2
#       3 age = int(input())
# ----> 4 assert age>=18, "age must be above 17"
#       5 print("eligible")
#
# AssertionError: age must be above 17

# %%
def add(a,b):
    return a+b 

a = int(input())
b = int(input())
res = add(a,b)
print(res)
# Out:
#  1
#  3
# 4
