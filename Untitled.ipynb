# %%
#reverse of a string
a = "codegnan" 
length = len(a)
string = a[::-1]
print(string)
# Out:
# nangedoc

# %%
#string operations
#1.string concatenation(using + operator)
#2. string repetition (using * op)
s1 = "code"
s2 = "gnan"
s3 = s1 + s2
print(s3)
# Out:
# codegnan

# %%
s1 = "python"
s2 = ("* " * 3 + s1 + " *" * 3 )
print(s2)
# Out:
# * * * python * * *

# %%
#slicing and concatenation
s = "codegnan"
string = s[:1] + z + s[
