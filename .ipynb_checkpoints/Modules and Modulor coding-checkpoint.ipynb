# %% [markdown]
# Module:
#     -A module is .py file and it consists of variables,functions and classes.
#     -can use the one module code in some another module by using importing module.
#
# Advantages:
#     -code reusablity
#     -easy to maintain
#     -easy to debug

# %% [markdown]
# process to create module in vs code:
#
# >mkdir modules
# >cd modules
# >code .
#
#     >then it redirects into 'vs code'
#
# >then add files in vs code > new terminal > in that +button then select gitbash then it rep like $ in that
#
# -to creat file in module
#
# example: addition
# $ touch addition.py
#
# >to run specific file in vs code:
#
# $ python addition.py
#
#
# #once created files with function name
# >we can write like
# >import module_name
# >print(module_name.function_name(x,y))
# >as for alias name like import module_name as module
# >for function also

# %% [markdown]
# #to install jupyter notebook
#
# >pip install jupyter
#
# to check version
#
# >jupyter --version
#
# #to check version of python
#
# >python --version
#
# #to open jupyter notebook through folder and path and in path> cmd > jupyter notebook > then it opens >to save >ctrl s
#
# #to push into github
#
# in cmd from path
#
# >git add .
# >git commit -m "file_name"
# >git push -u origin main
#
# >then it pushes into github
